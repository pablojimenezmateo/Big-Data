# %% [markdown]
# # Comparing speedups when using compression with blz btables

# %% [markdown]
# In this tutorial we are going to see the performance of the btable container using different compressors and compression levels. We are going to use the same dataset that we used in "Querying big datasets, the good way" notebook.

# %%
import pandas as pd
import numpy as np
import pylab as plt
import blz
import sys
import csv
from time import time
from shutil import rmtree
from collections import defaultdict

# %% [markdown]
# First, we read the dataset and store it as an uncompressed btable.

# %%
t1 = time()
df = pd.read_hdf('h5/msft-18-SEP-2013-blosc9.h5', '/msft')
t2 = time()

print "Reading h5: " + str(t2 - t1)

dt = np.dtype([(k, v if v.kind!='O' else 'S49') for k,v in df.dtypes.iteritems()])

#If the blz already exist, remove it
rmtree('msft-18-SEP-2013-blosc9.blz', ignore_errors=True)

t1 = time()
bt = blz.fromiter((i[1:] for i in df.itertuples()), rootdir='blz/msft-18-SEP-2013-blosc9.blz', dtype=dt, count=len(df), 
                  bparams=blz.bparams(clevel=0))
t2 = time()

print "Converting h5 to btable: " + str(t2 - t1)
# Out:
# Reading h5: 5.91825294495
# Converting h5 to btable: 12.1560459137

# %% [markdown]
# Let's create a function that will copy the blz.

# %%
def copy(src, dest, clevel=5, shuffle=True, cname="blosclz"):

    """

    Parameters
    ----------
    clevel : int (0 <= clevel < 10)
        The compression level.
    shuffle : bool
        Whether the shuffle filter is active or not.
    cname : string ('blosclz', 'lz4', 'lz4hc', 'snappy', 'zlib', others?)
        Select the compressor to use inside Blosc.

    """

    src = blz.btable(rootdir=src)
    
    img_copied = src.copy(rootdir=dest, bparams=blz.bparams(clevel=clevel, shuffle=shuffle, cname=cname))
    img_copied.flush()

# %% [markdown]
# We will take the [Open-High-Low-Close](http://en.wikipedia.org/wiki/Open-high-low-close_chart) points for that chart, for every level, for every compressor.

# %%
def get_OHLC_points(src):
    
    windows = []
    window_size = 79
    sample_size = 2455
    
    iter = src.where('(Type == \'Trade\')')

    for i in xrange(sample_size):
    
        local_max = - np.inf
        local_min = np.inf
        average_price = 0
    
        for j in xrange(window_size):
        
            current = iter.next()
            price = current[7]
            average_price += price
            
            if(price > local_max):
                local_max = price
            
            if(price < local_min):
                local_min = price
            
            if(j == 0):
                local_open = price
            
            if(j == (window_size - 1)):
                local_close = price
        
        windows.append([average_price/float(window_size), local_open, local_max, local_min, local_close])

# %% [markdown]
# And now we just need a benchmark function.

# %%
def benchmark(src, cmethods):

    for method in cmethods:

        myfile = open('csv/btable_' + method + '.csv', 'wb')
        wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
        wr.writerow(['Compression level', 'Compressed size', 'Compression ratio', 'Compression time', 'OHLC time'])

        for compression_level in xrange(0,10):

            #I get the original file and compress it
            tc1 = time()
            copy(src, 'blz/temp.blz', compression_level, True, method)
            tc2 = time()

            #Get disk size
            data = blz.btable(rootdir='blz/temp.blz')
            disk_size = data.cbytes

            #Now I get the poins and measure the time
            t1 = time()
            get_OHLC_points(data)
            t2 = time()

            #I should store the size of the file, compression method, shuffle and compression ratio
            row = [compression_level, disk_size, round(data.nbytes/float(disk_size),3), str(tc2 - tc1), str(t2 - t1)]

            #Add it to the csv
            wr.writerow(row)
            rmtree('blz/temp.blz', ignore_errors=True)

        myfile.close()

# %% [markdown]
# We now have all the ingredients, let's do some benchmarking.

# %%
src = 'blz/msft-18-SEP-2013-blosc9.blz'
cmethods = ['blosclz', 'lz4', 'lz4hc', 'snappy', 'zlib']

t1 = time()
benchmark(src, cmethods)
t2 = time()

print t2-t1
# Out:
# 768.129498959

# %% [markdown]
# We can now see all the gathered data.

# %%
print 'blosclz data'
df = pd.read_csv('csv/btable_blosclz.csv')
df
# Out:
# blosclz data
#    Compression level  Compressed size  Compression ratio  Compression time  \
# 0                  0        485063744              0.995          9.678071
# 1                  1         62562582              7.716          1.705340
# 2                  2         60615376              7.964          1.776808
# 3                  3         60114378              8.030          1.827085
# 4                  4         28904306             16.701          1.924027
# 5                  5         27821399             17.351          1.901335
# 6                  6         27450920             17.585          1.880923
# 7                  7         27136857             17.789          1.931791
# 8                  8         27091198             17.819          1.926020
# 9                  9         27033395             17.857          1.950624
#
#    OHLC time
# 0   2.911351
# 1   2.818488
# 2   2.826227
# 3   2.840619
# 4   3.072317
# 5   3.015017
# 6   3.023017
# 7   2.983236
# 8   2.981553
# 9   3.046549
#
# [10 rows x 5 columns]

# %%
print 'lz4 data'
df = pd.read_csv('csv/btable_lz4.csv')
df
# Out:
# lz4 data
#    Compression level  Compressed size  Compression ratio  Compression time  \
# 0                  0        485063744              0.995         10.338621
# 1                  1         31210120             15.467          1.676342
# 2                  2         31210120             15.467          1.673333
# 3                  3         31210120             15.467          1.669843
# 4                  4         31210120             15.467          1.662484
# 5                  5         31210120             15.467          1.662667
# 6                  6         31210120             15.467          1.717193
# 7                  7         31210120             15.467          1.673410
# 8                  8         31210120             15.467          1.679424
# 9                  9         31210120             15.467          1.668936
#
#    OHLC time
# 0   2.884691
# 1   2.912654
# 2   3.005816
# 3   2.868251
# 4   2.886794
# 5   2.859225
# 6   2.886366
# 7   2.903642
# 8   2.871548
# 9   2.920671
#
# [10 rows x 5 columns]

# %%
print 'lz4hc data'
df = pd.read_csv('csv/btable_lz4hc.csv')
df
# Out:
# lz4hc data
#    Compression level  Compressed size  Compression ratio  Compression time  \
# 0                  0        485063744              0.995          9.303392
# 1                  1         27466793             17.575          4.488822
# 2                  2         23961748             20.146          5.485580
# 3                  3         21717259             22.228          7.859126
# 4                  4         20475242             23.576         14.374430
# 5                  5         19908867             24.247         29.514525
# 6                  6         19752345             24.439         50.325230
# 7                  7         19711733             24.489         58.467600
# 8                  8         19710950             24.490         58.234206
# 9                  9         19710833             24.491         58.516145
#
#    OHLC time
# 0   3.244931
# 1   2.916096
# 2   2.863273
# 3   2.769077
# 4   2.845764
# 5   3.002939
# 6   2.836844
# 7   2.813690
# 8   2.851428
# 9   2.896298
#
# [10 rows x 5 columns]

# %%
print 'snappy data'
df = pd.read_csv('csv/btable_snappy.csv')
df
# Out:
# snappy data
#    Compression level  Compressed size  Compression ratio  Compression time  \
# 0                  0        485063744              0.995         10.031953
# 1                  1        410696358              1.175         11.284816
# 2                  2        410696358              1.175         10.957606
# 3                  3        410696358              1.175         11.438635
# 4                  4        410696358              1.175         11.088147
# 5                  5        410696358              1.175         11.116665
# 6                  6        410696358              1.175         11.413366
# 7                  7        410696358              1.175         11.453339
# 8                  8        410696358              1.175         11.429085
# 9                  9        410696358              1.175          7.494412
#
#    OHLC time
# 0   2.883290
# 1   2.997263
# 2   3.021066
# 3   2.893398
# 4   2.971917
# 5   3.005256
# 6   3.062698
# 7   3.033167
# 8   2.867020
# 9   3.089597
#
# [10 rows x 5 columns]

# %%
print 'zlib data'
df = pd.read_csv('csv/btable_zlib.csv')
df
# Out:
# zlib data
#    Compression level  Compressed size  Compression ratio  Compression time  \
# 0                  0        485063744              0.995         10.309105
# 1                  1         21562571             22.387          4.696151
# 2                  2         19985468             24.154          4.871047
# 3                  3         19364324             24.929          5.567336
# 4                  4         17011833             28.376          8.571385
# 5                  5         16773528             28.779          9.723062
# 6                  6         15251112             31.652         12.260388
# 7                  7         15156305             31.850         14.776852
# 8                  8         14295434             33.768         29.528989
# 9                  9         14114077             34.202         45.930716
#
#    OHLC time
# 0   2.975838
# 1   4.093263
# 2   4.008993
# 3   3.924213
# 4   4.218563
# 5   4.155369
# 6   4.026188
# 7   3.972700
# 8   4.030266
# 9   4.123026
#
# [10 rows x 5 columns]

# %% [raw]
# Let's do some more plotting. For that I first need to make some dictionaries out of this data.

# %%
def get_dict(filename):
    
    columns = defaultdict(list)
    with open('csv/btable_' + filename) as f:
        reader = csv.reader(f)
        reader.next()
        for row in reader:
            for (i,v) in enumerate(row):
                if i == 1:
                    columns[i].append(float(v)/131072)
                    continue
                columns[i].append(v)
    return columns

blosclz = get_dict('blosclz.csv')
lz4 = get_dict('lz4.csv')
lz4hc = get_dict('lz4hc.csv')
snappy = get_dict('snappy.csv')
zlib = get_dict('zlib.csv')

# %% [markdown]
# Now we are ready to plot.

# %%
# %matplotlib inline

#Matplotlib magic
fig = plt.figure(num=None, figsize=(18, 9), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
plt.subplots_adjust(wspace=0.6, hspace=0.6)
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')
ax.set_xlabel('Compression ratio')
ax.set_ylabel('Compression level')

#blosclz
ax1.set_title('blosclz')
ax1.plot(blosclz[2][2:], blosclz[0][2:], 'bo-')

#lz4
ax2.set_title('lz4')
ax2.plot(lz4[2][2:], blosclz[0][2:], 'bo-')

#lz4hc
ax3.set_title('lz4hc')
ax3.plot(lz4hc[2][2:], lz4hc[0][2:], 'bo-')

#snappy
ax4.set_title('snappy')
ax4.plot(snappy[2][2:], snappy[0][2:], 'bo-')

#zlib
ax5.set_title('zlib')
ax5.plot(zlib[2][2:], zlib[0][2:], 'bo-')

plt.show()

# %% [markdown]
# We can see that except with snappy and lz4, we get a higher compression ratio with a higher compression level.

# %%
#Matplotlib magic
fig = plt.figure(num=None, figsize=(18, 9), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
plt.subplots_adjust(wspace=0.6, hspace=0.6)
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')
ax.set_xlabel('Compression time (s)')
ax.set_ylabel('Compression ratio')

#blosclz
ax1.set_title('blosclz')
ax1.plot(blosclz[3][2:], blosclz[2][2:], 'bo-')

#lz4
ax2.set_title('lz4')
ax2.plot(lz4[3][2:], blosclz[2][2:], 'bo-')

#lz4hc
ax3.set_title('lz4hc')
ax3.plot(lz4hc[3][2:], lz4hc[2][2:], 'bo-')

#snappy
ax4.set_title('snappy')
ax4.plot(snappy[3][2:], snappy[2][2:], 'bo-')

#zlib
ax5.set_title('zlib')
ax5.plot(zlib[3][2:], zlib[2][2:], 'bo-')

plt.show()

# %% [markdown]
# Again except with snappy and lz4 (and blosclz behaves strangely), we can see that a higher compression ratio needs a higher time.

# %%
#Matplotlib magic
fig = plt.figure(num=None, figsize=(18, 9), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
plt.subplots_adjust(wspace=0.6, hspace=0.6)
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')
ax.set_xlabel('OHLC time (s)')
ax.set_ylabel('Compression level')

#X value for red line
X = (float(blosclz[4][1]) + float(lz4[4][1]) + float(lz4hc[4][1]) + float(snappy[4][1]) + float(zlib[4][1]))/len(cmethods)

#blosclz
ax1.set_title('blosclz')
ax1.plot(blosclz[4][2:], blosclz[0][2:], 'bo-')
ax1.axvline(X, color = 'r')

#lz4
ax2.set_title('lz4')
ax2.plot(lz4[4][2:], blosclz[0][2:], 'bo-')
ax2.axvline(X, color = 'r')

#lz4hc
ax3.set_title('lz4hc')
ax3.plot(lz4hc[4][2:], lz4hc[0][2:], 'bo-')
ax3.axvline(X, color = 'r')

#snappy
ax4.set_title('snappy')
ax4.plot(snappy[4][2:], snappy[0][2:], 'bo-')
ax4.axvline(X, color = 'r')

#zlib
ax5.set_title('zlib')
ax5.plot(zlib[4][2:], zlib[0][2:], 'bo-')
ax5.axvline(X, color = 'r')

plt.show()

# %% [markdown]
# The red line represents the OHLC time for the uncompressed blz (Mean of 4 tries), so everything to its left is faster than the uncompressed data.
#
# We here can see that except with zlib, it is actually better to compress the data rather than to have it uncompressed (Better computational times)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Reading from disk is a really slow operation, you should compress your data.
