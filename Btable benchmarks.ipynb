# %% [markdown]
# # Comparing speedups when using compression with blz btables

# %% [markdown]
# In this tutorial we are going to see the performance of the btable container using different compressors and compression levels. We are going to use the same dataset that we used in "Querying big datasets, the good way" notebook.

# %%
import pandas as pd
import numpy as np
import pylab as plt
import blz
import sys
import csv
from time import time
from shutil import rmtree
from collections import defaultdict

# %% [markdown]
# First, we read the dataset and store it as an uncompressed btable.

# %%
t1 = time()
df = pd.read_hdf('h5/msft-18-SEP-2013-blosc9.h5', '/msft')
t2 = time()

print "Reading h5: " + str(t2 - t1)

dt = np.dtype([(k, v if v.kind!='O' else 'S49') for k,v in df.dtypes.iteritems()])

#If the blz already exist, remove it
rmtree('blz/msft-18-SEP-2013-blosc9.blz', ignore_errors=True)

t1 = time()
bt = blz.fromiter((i[1:] for i in df.itertuples()), rootdir='blz/msft-18-SEP-2013-blosc9.blz', dtype=dt, count=len(df), 
                  bparams=blz.bparams(clevel=0))
t2 = time()

print "Converting h5 to btable: " + str(t2 - t1)
# Out:
# Reading h5: 6.13729596138
# Converting h5 to btable: 8.69978094101

# %% [markdown]
# Let's create a function that will copy the blz.

# %%
def copy(src, dest, clevel=5, shuffle=True, cname="blosclz"):

    """

    Parameters
    ----------
    clevel : int (0 <= clevel < 10)
        The compression level.
    shuffle : bool
        Whether the shuffle filter is active or not.
    cname : string ('blosclz', 'lz4', 'lz4hc', 'snappy', 'zlib', others?)
        Select the compressor to use inside Blosc.

    """

    src = blz.btable(rootdir=src)
    
    copied = src.copy(rootdir=dest, bparams=blz.bparams(clevel=clevel, shuffle=shuffle, cname=cname))
    copied.flush()

# %% [markdown]
# We will take the [Open-High-Low-Close](http://en.wikipedia.org/wiki/Open-high-low-close_chart) points for that chart, for every level, for every compressor.

# %%
def get_OHLC_points(src):
    
    windows = []
    window_size = 79
    sample_size = 2455
    
    iter = src.where('(Type == \'Trade\')')

    for i in xrange(sample_size):
    
        local_max = - np.inf
        local_min = np.inf
        average_price = 0
    
        for j in xrange(window_size):
        
            current = iter.next()
            price = current[7]
            average_price += price
            
            if(price > local_max):
                local_max = price
            
            if(price < local_min):
                local_min = price
            
            if(j == 0):
                local_open = price
            
            if(j == (window_size - 1)):
                local_close = price
        
        windows.append([average_price/float(window_size), local_open, local_max, local_min, local_close])

# %% [markdown]
# And now we just need a benchmark function.

# %%
def benchmark(src, cmethods):

    for method in cmethods:

        myfile = open('csv/btable_' + method + '.csv', 'wb')
        wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
        wr.writerow(['Compression level',
                     'Compressed size',
                     'Compression ratio',
                     'Compression time',
                     'OHLC time',
                     'Writing speed (MiB/s)',
                     'OHLC speed (MiB/s)'])
        
        for compression_level in xrange(0,10):

            #I get the original file and compress it
            tc1 = time()
            copy(src, 'blz/temp.blz', compression_level, True, method)
            tc2 = time()

            #Get disk size
            data = blz.btable(rootdir='blz/temp.blz')
            
            #Uncompressed size in MiB
            uncompressed = data.nbytes/(2**20)
            
            #Now I get the poins and measure the time
            t1 = time()
            get_OHLC_points(data)
            t2 = time()

            #I should store stuff
            row = [compression_level, data.cbytes,
                   round(data.nbytes/float(data.cbytes),3),
                   str(tc2 - tc1),
                   str(t2 - t1),
                   uncompressed/(tc2 - tc1),
                   uncompressed/(t2 - t1)]

            #Add it to the csv
            wr.writerow(row)
            rmtree('blz/temp.blz', ignore_errors=True)

        myfile.close()

# %% [markdown]
# We have all the ingredients now, let's do some benchmarking.

# %%
src = 'blz/msft-18-SEP-2013-blosc9.blz'
cmethods = ['blosclz', 'lz4', 'lz4hc', 'snappy', 'zlib']

t1 = time()
benchmark(src, cmethods)
t2 = time()

print t2-t1
# Out:
# 644.996655941

# %% [markdown]
# We can see all the gathered data now.

# %%
print 'blosclz data'
df = pd.read_csv('csv/btable_blosclz.csv')
df
# Out:
# blosclz data
#    Compression level  Compressed size  Compression ratio  Compression time  \
# 0                  0        485063744              0.995          2.016147
# 1                  1         62562582              7.716          1.695872
# 2                  2         60615376              7.964          1.748772
# 3                  3         60114378              8.030          1.821838
# 4                  4         28904306             16.701          1.891148
# 5                  5         27821399             17.351          1.914200
# 6                  6         27450920             17.585          1.901887
# 7                  7         27136857             17.789          1.904645
# 8                  8         27091198             17.819          1.910367
# 9                  9         27033395             17.857          1.946188
#
#    OHLC time  Writing speed (MiB/s)  OHLC speed (MiB/s)
# 0   2.821242             228.157951          163.048751
# 1   2.893117             271.246876          158.998066
# 2   2.768387             263.041737          166.161735
# 3   2.822847             252.492277          162.956057
# 4   2.948612             243.238487          156.005607
# 5   2.993332             240.309259          153.674906
# 6   2.982649             241.865061          154.225317
# 7   3.009952             241.514827          152.826354
# 8   2.991939             240.791428          153.746447
# 9   2.933881             236.359492          156.788906
#
# [10 rows x 7 columns]

# %%
print 'lz4 data'
df = pd.read_csv('csv/btable_lz4.csv')
df
# Out:
# lz4 data
#    Compression level  Compressed size  Compression ratio  Compression time  \
# 0                  0        485063744              0.995          1.840693
# 1                  1         31210120             15.467          1.654439
# 2                  2         31210120             15.467          1.665296
# 3                  3         31210120             15.467          1.665405
# 4                  4         31210120             15.467          1.686232
# 5                  5         31210120             15.467          1.681519
# 6                  6         31210120             15.467          1.657978
# 7                  7         31210120             15.467          1.682434
# 8                  8         31210120             15.467          1.660968
# 9                  9         31210120             15.467          1.664384
#
#    OHLC time  Writing speed (MiB/s)  OHLC speed (MiB/s)
# 0   2.845191             249.905878          161.676316
# 1   3.082567             278.039872          149.226279
# 2   2.820905             276.227156          163.068237
# 3   2.831150             276.209124          162.478142
# 4   2.866461             272.797599          160.476627
# 5   2.839322             273.562173          162.010517
# 6   2.840621             277.446374          161.936422
# 7   2.814919             273.413387          163.415004
# 8   2.838577             276.946926          162.053027
# 9   2.806845             276.378507          163.885077
#
# [10 rows x 7 columns]

# %%
print 'lz4hc data'
df = pd.read_csv('csv/btable_lz4hc.csv')
df
# Out:
# lz4hc data
#    Compression level  Compressed size  Compression ratio  Compression time  \
# 0                  0        485063744              0.995          1.856075
# 1                  1         27466793             17.575          4.442873
# 2                  2         23961748             20.146          5.475768
# 3                  3         21717259             22.228          7.846703
# 4                  4         20475242             23.576         14.341051
# 5                  5         19908867             24.247         29.603574
# 6                  6         19752345             24.439         50.244843
# 7                  7         19711733             24.489         58.036335
# 8                  8         19710950             24.490         58.294637
# 9                  9         19710833             24.491         58.406095
#
#    OHLC time  Writing speed (MiB/s)  OHLC speed (MiB/s)
# 0   2.856277             247.834806          161.048806
# 1   2.760939             103.536608          166.609990
# 2   2.749967              84.006480          167.274729
# 3   2.790167              58.623348          164.864678
# 4   2.829733              32.075752          162.559499
# 5   2.765928              15.538664          166.309461
# 6   2.852037               9.155168          161.288233
# 7   2.796057               7.926069          164.517391
# 8   2.808176               7.890949          163.807394
# 9   2.741073               7.875890          167.817500
#
# [10 rows x 7 columns]

# %%
print 'snappy data'
df = pd.read_csv('csv/btable_snappy.csv')
df
# Out:
# snappy data
#    Compression level  Compressed size  Compression ratio  Compression time  \
# 0                  0        485063744              0.995          1.843317
# 1                  1        410696358              1.175          1.997833
# 2                  2        410696358              1.175          2.003207
# 3                  3        410696358              1.175          2.009446
# 4                  4        410696358              1.175          2.009583
# 5                  5        410696358              1.175          2.008898
# 6                  6        410696358              1.175          2.016808
# 7                  7        410696358              1.175          2.027532
# 8                  8        410696358              1.175          2.002294
# 9                  9        410696358              1.175          1.997915
#
#    OHLC time  Writing speed (MiB/s)  OHLC speed (MiB/s)
# 0   2.884040             249.550127          159.498475
# 1   3.111893             230.249474          147.819995
# 2   2.999845             229.631762          153.341255
# 3   2.997088             228.918800          153.482316
# 4   2.998983             228.903211          153.385336
# 5   3.038415             228.981287          151.394726
# 6   3.012682             228.083185          152.687861
# 7   3.036895             226.876803          151.470497
# 8   2.969663             229.736485          154.899736
# 9   2.922584             230.240022          157.394960
#
# [10 rows x 7 columns]

# %%
print 'zlib data'
df = pd.read_csv('csv/btable_zlib.csv')
df
# Out:
# zlib data
#    Compression level  Compressed size  Compression ratio  Compression time  \
# 0                  0        485063744              0.995          1.839286
# 1                  1         21562571             22.387          4.711031
# 2                  2         19985468             24.154          4.895662
# 3                  3         19364324             24.929          5.589531
# 4                  4         17011833             28.376          8.849895
# 5                  5         16773528             28.779          9.966427
# 6                  6         15251112             31.652         12.172043
# 7                  7         15156305             31.850         14.715484
# 8                  8         14295434             33.768         29.546444
# 9                  9         14114077             34.202         45.731675
#
#    OHLC time  Writing speed (MiB/s)  OHLC speed (MiB/s)
# 0   2.854603             250.097069          161.143245
# 1   4.071606              97.643171          112.977535
# 2   3.904517              93.960734          117.812269
# 3   4.048691              82.296709          113.616975
# 4   4.048908              51.978018          113.610880
# 5   4.030304              46.154956          114.135312
# 6   3.965391              37.791519          116.003695
# 7   4.010091              31.259590          114.710612
# 8   3.993901              15.568709          115.175614
# 9   3.956451              10.058674          116.265817
#
# [10 rows x 7 columns]

# %% [markdown]
# Let's do some more plotting. For that I first need to make some dictionaries out of this data.

# %%
def get_dict(filename):
    
    columns = defaultdict(list)
    with open('csv/btable_' + filename) as f:
        reader = csv.reader(f)
        reader.next()
        for row in reader:
            for (i,v) in enumerate(row):
                if i == 1:
                    columns[i].append(float(v)/131072)
                    continue
                columns[i].append(v)
    return columns

blosclz = get_dict('blosclz.csv')
lz4 = get_dict('lz4.csv')
lz4hc = get_dict('lz4hc.csv')
snappy = get_dict('snappy.csv')
zlib = get_dict('zlib.csv')

# %% [markdown]
# Now we are ready to plot.

# %%
# %matplotlib inline

#Matplotlib magic
fig = plt.figure(num=None, figsize=(18, 9), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
plt.subplots_adjust(wspace=0.6, hspace=0.6)
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')
ax.set_xlabel('Compression ratio')
ax.set_ylabel('Compression level')

#blosclz
ax1.set_title('blosclz')
ax1.plot(blosclz[2][1:], blosclz[0][1:], 'bo-')

#lz4
ax2.set_title('lz4')
ax2.plot(lz4[2][1:], blosclz[0][1:], 'bo-')

#lz4hc
ax3.set_title('lz4hc')
ax3.plot(lz4hc[2][1:], lz4hc[0][1:], 'bo-')

#snappy
ax4.set_title('snappy')
ax4.plot(snappy[2][1:], snappy[0][1:], 'bo-')

#zlib
ax5.set_title('zlib')
ax5.plot(zlib[2][1:], zlib[0][1:], 'bo-')

plt.show()

# %% [markdown]
# We can see that except with snappy and lz4, we get a higher compression ratio with a higher compression level.

# %%
#Matplotlib magic
fig = plt.figure(num=None, figsize=(18, 9), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
plt.subplots_adjust(wspace=0.6, hspace=0.6)
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')
ax.set_ylabel('Compression time (s)')
ax.set_xlabel('Compression ratio')

#blosclz
ax1.set_title('blosclz')
ax1.plot(blosclz[2][1:], blosclz[3][1:], 'bo-')

#lz4
ax2.set_title('lz4')
ax2.plot(lz4[2][1:], blosclz[3][1:], 'bo-')

#lz4hc
ax3.set_title('lz4hc')
ax3.plot(lz4hc[2][1:], lz4hc[3][1:], 'bo-')

#snappy
ax4.set_title('snappy')
ax4.plot(snappy[2][1:], snappy[3][1:], 'bo-')

#zlib
ax5.set_title('zlib')
ax5.plot(zlib[2][1:], zlib[3][1:], 'bo-')

plt.show()

# %% [markdown]
# Again except with snappy and lz4 (and blosclz behaves strangely), we can see that a higher compression ratio needs a higher time.

# %%
#Matplotlib magic
fig = plt.figure(num=None, figsize=(18, 9), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111)
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(232)
ax3 = fig.add_subplot(233)
ax4 = fig.add_subplot(234)
ax5 = fig.add_subplot(235)
plt.subplots_adjust(wspace=0.6, hspace=0.6)
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')
ax.set_ylabel('OHLC time (s)')
ax.set_xlabel('Compression level')

#Y value for red line
Y = (float(blosclz[4][1]) + float(lz4[4][1]) + float(lz4hc[4][1]) + float(snappy[4][1]) + float(zlib[4][1]))/len(cmethods)

#blosclz
ax1.set_title('blosclz')
ax1.plot(blosclz[0][1:], blosclz[4][1:], 'bo-')
ax1.axhline(Y, color = 'r')

#lz4
ax2.set_title('lz4')
ax2.plot(lz4[0][1:], blosclz[4][1:], 'bo-')
ax2.axhline(Y, color = 'r')

#lz4hc
ax3.set_title('lz4hc')
ax3.plot(lz4hc[0][1:], lz4hc[4][1:], 'bo-')
ax3.axhline(Y, color = 'r')

#snappy
ax4.set_title('snappy')
ax4.plot(snappy[0][1:], snappy[4][1:], 'bo-')
ax4.axhline(Y, color = 'r')

#zlib
ax5.set_title('zlib')
ax5.plot(zlib[0][1:], zlib[4][1:], 'bo-')
ax5.axhline(Y, color = 'r')

plt.show()

# %% [markdown]
# The red line represents the OHLC time for the uncompressed blz (Mean of 4 tries), so everything lower is faster than the uncompressed data.
#
# We here can see that except with zlib, it is actually better to compress the data rather than to have it uncompressed (Better computational times)

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Reading from disk is a really slow operation, you should compress your data.
